# %% [markdown]
# # Python Crash Course
# ## Chapter#9 : Classes
#
# Object-oriented programming is one of the most effective approaches to writing software. In object-oriented programming you write clsases that represent real-world things and situations, and you create objects based on these classes. When you write a class, you define the general behavior that a whole category of objects can have
#
# ## Creating and Using a Class
#
# You can model almost anyhing using classes. AFter our class is written we'll use it to make individual instances.

# %%
class Dog():
    """A simple attempt to model a dog"""
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def sit(self):
        """Simulate a dog sitting in response to a command"""
        print(self.name.title() + " is now sitting.")
    
    def roll_over(self):
        """Simulate a dog sitting in response to a command"""
        print(self.name.title() + " rolled over!")

# %% [markdown]
# ### The __init__() Method
#
# A function thats part of a class is called a method. The __ init() __ method is a special method Python runs automatically whenever we create a new instance based on the Dog Class/ This method has two leading and trainling underscores, a convention that prevents Pythons default method names from conflicting with our method names.
#
# We define __ init() __ to have 3 parameters: self, name, and age. The self parameter is required in the method definition and it must come first before the others parameters.
#
# ### Creating an Instance of a Class & Accessing its attributes
#
# Lets make an instance representing a specific dog and see how we can access its attributes

# %%
my_dog = Dog('Willie', 6)
print("My dogs name is " + my_dog.name.title())
print("My dog is " + str(my_dog.age) + " years old.")
# Out:
# My dogs name is Willie
# My dog is 6 years old.

# %% [markdown]
# ### Calling Methods
#
# After we create an instance from the class Dog we can use dot notation to call any method defined in Dog. Lets make our dog sit and roll over

# %%
my_dog.sit()
my_dog.roll_over()
# Out:
# Willie is now sitting.
# Willie rolled over!

# %% [markdown]
# ### Creating Multiple Instance
#
# You can create multiple instances of a Dog
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
